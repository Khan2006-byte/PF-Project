# %% [markdown]
# ## **Data creation** ##

# %%
import pandas as pd
h = pd.read_csv("pf.file.csv")  # read the file
h
# Out:
#     Customer ID               Category                Item  Quantity  \
# 0     CUST_0194                Hobbies    Crochet Supplies       5.0
# 1     CUST_0152       Personal Hygiene                Soap       3.0
# 2     CUST_0013                  Gifts                 NaN       1.0
# 3     CUST_0189                Fitness    Personal Trainer       5.0
# 4     CUST_0022          Subscriptions            Magazine       1.0
# ..          ...                    ...                 ...       ...
# 995         NaN         Medical/Dental       Dentist Visit       1.0
# 996   CUST_0103  Housing and Utilities    Electricity Bill       1.0
# 997   CUST_0193         Medical/Dental            Medicine       1.0
# 998   CUST_0165      Friend Activities       Movie Tickets       5.0
# 999   CUST_0047       Personal Hygiene  Skin Care Products       1.0
#
#      Price Per Unit  Total Spent  Payment Method    Location Transaction Date
# ...

# %% [markdown]
# ### _**Data Exploration (Initial Analysis)**_

# %%
h.head()  # get the first 5 rows
# Out:
#   Customer ID          Category              Item  Quantity  Price Per Unit  \
# 0   CUST_0194           Hobbies  Crochet Supplies       5.0           10.68
# 1   CUST_0152  Personal Hygiene              Soap       3.0            5.14
# 2   CUST_0013             Gifts               NaN       1.0          386.06
# 3   CUST_0189           Fitness  Personal Trainer       5.0          155.46
# 4   CUST_0022     Subscriptions          Magazine       1.0            5.82
#
#    Total Spent  Payment Method    Location Transaction Date
# 0        53.40     Credit Card  Mobile App         1/8/2024
# 1        15.43  Digital Wallet  Mobile App        11/6/2023
# 2       386.06  Digital Wallet    In-store       12/28/2024
# 3       777.29  Digital Wallet         NaN       10/24/2023
# 4         5.82      Debit Card      Online        7/12/2023

# %%
h.tail()  # get the last 5 rows
# Out:
#     Customer ID               Category                Item  Quantity  \
# 995         NaN         Medical/Dental       Dentist Visit       1.0
# 996   CUST_0103  Housing and Utilities    Electricity Bill       1.0
# 997   CUST_0193         Medical/Dental            Medicine       1.0
# 998   CUST_0165      Friend Activities       Movie Tickets       5.0
# 999   CUST_0047       Personal Hygiene  Skin Care Products       1.0
#
#      Price Per Unit  Total Spent Payment Method    Location Transaction Date
# 995          189.59       189.59            NaN  Mobile App         9/6/2023
# 996          162.28       162.28           Cash  Mobile App        5/23/2024
# 997          720.00       720.00     Debit Card      Online       11/10/2023
# 998           13.28        66.40     Debit Card  Mobile App        10/2/2024
# 999          390.94       390.94    Credit Card    In-store       11/17/2023

# %%
h.sample(10)   # get a random sample of 10 rows
# Out:
#     Customer ID               Category              Item  Quantity  \
# 474   CUST_0171                  Gifts           Flowers       4.0
# 487   CUST_0008                  Gifts           Jewelry       1.0
# 418   CUST_0024                Fitness  Personal Trainer       NaN
# 430   CUST_0070                    NaN            Coffee       3.0
# 160   CUST_0083                   Food         Fast Food       2.0
# 617   CUST_0019                Hobbies       Video Games       2.0
# 976         NaN      Friend Activities   Concert Tickets       NaN
# 319   CUST_0145                Fitness               NaN       4.0
# 268   CUST_0121  Housing and Utilities  Electricity Bill       1.0
# 813   CUST_0098         Transportation        Car Repair       1.0
#
#      Price Per Unit  Total Spent  Payment Method    Location Transaction Date
# 474             NaN        94.70            Cash    In-store         7/2/2023
# ...

# %%
h.size   # get the size of the data
# Out:
# 9000

# %%
h.shape  # get the shape of the data
# Out:
# (1000, 9)

# %%
h.columns    # get the columns
# Out:
# Index(['Customer ID', 'Category', 'Item', 'Quantity', 'Price Per Unit',
#        'Total Spent', 'Payment Method', 'Location', 'Transaction Date'],
#       dtype='object')

# %%
h.info()  # get the info of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer ID       918 non-null    object
#  1   Category          914 non-null    object
#  2   Item              897 non-null    object
#  3   Quantity          895 non-null    float64
#  4   Price Per Unit    913 non-null    float64
#  5   Total Spent       896 non-null    float64
#  6   Payment Method    898 non-null    object
#  7   Location          902 non-null    object
#  8   Transaction Date  907 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 70.4+ KB

# %%
h.isnull().sum() # get the sum of missing values
# Out:
# Customer ID          82
# Category             86
# Item                103
# Quantity            105
# Price Per Unit       87
# Total Spent         104
# Payment Method      102
# Location             98
# Transaction Date     93
# dtype: int64

# %%
h[h["Category"].isnull()] # get the rows with missing values
# Out:
#     Customer ID Category              Item  Quantity  Price Per Unit  \
# 24    CUST_0187      NaN     Dentist Visit       1.0          125.61
# 30    CUST_0168      NaN        Toothpaste       NaN            4.21
# 58    CUST_0038      NaN               Gas       1.0           68.86
# 68    CUST_0012      NaN     Dentist Visit       1.0          412.05
# 90    CUST_0106      NaN  Crochet Supplies       NaN           50.08
# ..          ...      ...               ...       ...             ...
# 940   CUST_0189      NaN               NaN       1.0          178.63
# 941   CUST_0121      NaN            Coffee       1.0            3.90
# 965         NaN      NaN  Personal Trainer       5.0          127.16
# 987   CUST_0119      NaN              Soap       5.0            7.58
# 989   CUST_0134      NaN     Movie Tickets       5.0           15.98
#
#      Total Spent  Payment Method    Location Transaction Date
# 24        125.61     Credit Card  Mobile App        8/20/2024
# ...

# %%
h.describe(include="all") # get the summary statistics
# Out:
#        Customer ID          Category             Item    Quantity  \
# count          918               914              897  895.000000
# unique         198                13               48         NaN
# top      CUST_0142  Personal Hygiene  Restaurant Meal         NaN
# freq            12                83               28         NaN
# mean           NaN               NaN              NaN    2.302793
# std            NaN               NaN              NaN    1.488563
# min            NaN               NaN              NaN    1.000000
# 25%            NaN               NaN              NaN    1.000000
# 50%            NaN               NaN              NaN    2.000000
# 75%            NaN               NaN              NaN    4.000000
# max            NaN               NaN              NaN    5.000000
#
#         Price Per Unit    Total Spent  Payment Method  Location  \
# count       913.000000     896.000000             898       902
# ...

# %% [markdown]
# ### _**Data Cleaning**_

# %%
h.rename(columns={"Transaction Date":"date","Customer ID":"ID"})  # rename columns
# Out:
#             ID               Category                Item  Quantity  \
# 0    CUST_0194                Hobbies    Crochet Supplies       5.0
# 1    CUST_0152       Personal Hygiene                Soap       3.0
# 2    CUST_0013                  Gifts                 NaN       1.0
# 3    CUST_0189                Fitness    Personal Trainer       5.0
# 4    CUST_0022          Subscriptions            Magazine       1.0
# ..         ...                    ...                 ...       ...
# 995        NaN         Medical/Dental       Dentist Visit       1.0
# 996  CUST_0103  Housing and Utilities    Electricity Bill       1.0
# 997  CUST_0193         Medical/Dental            Medicine       1.0
# 998  CUST_0165      Friend Activities       Movie Tickets       5.0
# 999  CUST_0047       Personal Hygiene  Skin Care Products       1.0
#
#      Price Per Unit  Total Spent  Payment Method    Location        date
# 0             10.68        53.40     Credit Card  Mobile App    1/8/2024
# ...

# %%
h.dropna() # drop missing values
# Out:
#     Customer ID               Category                Item  Quantity  \
# 0     CUST_0194                Hobbies    Crochet Supplies       5.0
# 1     CUST_0152       Personal Hygiene                Soap       3.0
# 4     CUST_0022          Subscriptions            Magazine       1.0
# 7     CUST_0142                  Gifts             Jewelry       5.0
# 8     CUST_0115                Hobbies    Crochet Supplies       4.0
# ..          ...                    ...                 ...       ...
# 992   CUST_0103              Groceries                Meat       4.0
# 996   CUST_0103  Housing and Utilities    Electricity Bill       1.0
# 997   CUST_0193         Medical/Dental            Medicine       1.0
# 998   CUST_0165      Friend Activities       Movie Tickets       5.0
# 999   CUST_0047       Personal Hygiene  Skin Care Products       1.0
#
#      Price Per Unit  Total Spent  Payment Method    Location Transaction Date
# ...

# %%
k = h.fillna(value="wee")  # fillna() is used to fill the missing values in the dataframe
k
# Out:
#     Customer ID               Category                Item Quantity  \
# 0     CUST_0194                Hobbies    Crochet Supplies      5.0
# 1     CUST_0152       Personal Hygiene                Soap      3.0
# 2     CUST_0013                  Gifts                 wee      1.0
# 3     CUST_0189                Fitness    Personal Trainer      5.0
# 4     CUST_0022          Subscriptions            Magazine      1.0
# ..          ...                    ...                 ...      ...
# 995         wee         Medical/Dental       Dentist Visit      1.0
# 996   CUST_0103  Housing and Utilities    Electricity Bill      1.0
# 997   CUST_0193         Medical/Dental            Medicine      1.0
# 998   CUST_0165      Friend Activities       Movie Tickets      5.0
# 999   CUST_0047       Personal Hygiene  Skin Care Products      1.0
#
#     Price Per Unit Total Spent  Payment Method    Location Transaction Date
# ...

# %%
k = h["Total Spent"] # get the column
k
# Out:
# 0       53.40
# 1       15.43
# 2      386.06
# 3      777.29
# 4        5.82
#         ...
# 995    189.59
# 996    162.28
# 997    720.00
# 998     66.40
# 999    390.94
# Name: Total Spent, Length: 1000, dtype: float64

# %%
b=h[["Payment Method","Total Spent"]] # get the columns
b.head(10)
# Out:
#    Payment Method  Total Spent
# 0     Credit Card        53.40
# 1  Digital Wallet        15.43
# 2  Digital Wallet       386.06
# 3  Digital Wallet       777.29
# 4      Debit Card         5.82
# 5      Debit Card        12.00
# 6            Cash        53.53
# 7  Digital Wallet      2442.23
# 8     Credit Card       108.77
# 9     Credit Card       324.17

# %%
h.index  # get the index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
h["final"] = h["Price Per Unit"].fillna(h["Price Per Unit"].mean()) # fill the missing values with the mean
h[h["Price Per Unit"].isnull()]
# Out:
#     Customer ID           Category               Item  Quantity  \
# 6           NaN   Personal Hygiene            Shampoo       4.0
# 12    CUST_0026            Fitness  Workout Equipment       NaN
# 14          NaN          Groceries                NaN       1.0
# 35    CUST_0125            Hobbies   Crochet Supplies       4.0
# 63    CUST_0176  Friend Activities    Concert Tickets       1.0
# ..          ...                ...                ...       ...
# 901   CUST_0018             Travel          Taxi/Uber       1.0
# 934   CUST_0083            Fitness  Workout Equipment       3.0
# 937   CUST_0116   Personal Hygiene         Toothpaste       5.0
# 958   CUST_0120          Groceries         Vegetables       1.0
# 959   CUST_0108             Travel       Plane Ticket       1.0
#
#      Price Per Unit  Total Spent  Payment Method    Location Transaction Date  \
# 6               NaN        53.53            Cash    In-store       12/14/2023
# ...

# %%
h=h.drop(columns=["Location"]) # drop columns
h
# Out:
#     Customer ID               Category                Item  Quantity  \
# 0     CUST_0194                Hobbies    Crochet Supplies       5.0
# 1     CUST_0152       Personal Hygiene                Soap       3.0
# 2     CUST_0013                  Gifts                 NaN       1.0
# 3     CUST_0189                Fitness    Personal Trainer       5.0
# 4     CUST_0022          Subscriptions            Magazine       1.0
# ..          ...                    ...                 ...       ...
# 995         NaN         Medical/Dental       Dentist Visit       1.0
# 996   CUST_0103  Housing and Utilities    Electricity Bill       1.0
# 997   CUST_0193         Medical/Dental            Medicine       1.0
# 998   CUST_0165      Friend Activities       Movie Tickets       5.0
# 999   CUST_0047       Personal Hygiene  Skin Care Products       1.0
#
#      Price Per Unit  Total Spent  Payment Method Transaction Date   final
# ...

# %%
df = h.drop(3) # drop the row
df
# Out:
#     Customer ID               Category                Item  Quantity  \
# 0     CUST_0194                Hobbies    Crochet Supplies       5.0
# 1     CUST_0152       Personal Hygiene                Soap       3.0
# 2     CUST_0013                  Gifts                 NaN       1.0
# 4     CUST_0022          Subscriptions            Magazine       1.0
# 5     CUST_0097          Subscriptions            Magazine       1.0
# ..          ...                    ...                 ...       ...
# 995         NaN         Medical/Dental       Dentist Visit       1.0
# 996   CUST_0103  Housing and Utilities    Electricity Bill       1.0
# 997   CUST_0193         Medical/Dental            Medicine       1.0
# 998   CUST_0165      Friend Activities       Movie Tickets       5.0
# 999   CUST_0047       Personal Hygiene  Skin Care Products       1.0
#
#      Price Per Unit  Total Spent  Payment Method Transaction Date   final
# ...

# %% [markdown]
# ### _**Data Manipulation**_

# %%
h.insert(5, "price", 6) # insert a column
h
# Out:
#     Customer ID               Category                Item  Quantity  \
# 0     CUST_0194                Hobbies    Crochet Supplies       5.0
# 1     CUST_0152       Personal Hygiene                Soap       3.0
# 2     CUST_0013                  Gifts                 NaN       1.0
# 3     CUST_0189                Fitness    Personal Trainer       5.0
# 4     CUST_0022          Subscriptions            Magazine       1.0
# ..          ...                    ...                 ...       ...
# 995         NaN         Medical/Dental       Dentist Visit       1.0
# 996   CUST_0103  Housing and Utilities    Electricity Bill       1.0
# 997   CUST_0193         Medical/Dental            Medicine       1.0
# 998   CUST_0165      Friend Activities       Movie Tickets       5.0
# 999   CUST_0047       Personal Hygiene  Skin Care Products       1.0
#
#      Price Per Unit  price  Total Spent  Payment Method Transaction Date  \
# ...

# %%
# Calculate Total earning
h["Total earning"] = h["Quantity"] + h["Total Spent"]
h
# Out:
#     Customer ID               Category                Item  Quantity  \
# 0     CUST_0194                Hobbies    Crochet Supplies       5.0
# 1     CUST_0152       Personal Hygiene                Soap       3.0
# 2     CUST_0013                  Gifts                 NaN       1.0
# 3     CUST_0189                Fitness    Personal Trainer       5.0
# 4     CUST_0022          Subscriptions            Magazine       1.0
# ..          ...                    ...                 ...       ...
# 995         NaN         Medical/Dental       Dentist Visit       1.0
# 996   CUST_0103  Housing and Utilities    Electricity Bill       1.0
# 997   CUST_0193         Medical/Dental            Medicine       1.0
# 998   CUST_0165      Friend Activities       Movie Tickets       5.0
# 999   CUST_0047       Personal Hygiene  Skin Care Products       1.0
#
#      Price Per Unit  price  Total Spent  Payment Method Transaction Date  \
# ...

# %%
h['In.mean']=h["Total Spent"].mean() # calculate the mean
h['In.mean']
# Out:
# 0      2645.720904
# 1      2645.720904
# 2      2645.720904
# 3      2645.720904
# 4      2645.720904
#           ...
# 995    2645.720904
# 996    2645.720904
# 997    2645.720904
# 998    2645.720904
# 999    2645.720904
# Name: In.mean, Length: 1000, dtype: float64

# %% [markdown]
# ### _**Data Selection**_

# %%
h.loc[5]
# Out:
# Customer ID             CUST_0097
# Category            Subscriptions
# Item                     Magazine
# Quantity                      1.0
# Price Per Unit               12.0
# price                           6
# Total Spent                  12.0
# Payment Method         Debit Card
# Transaction Date         9/1/2023
# final                        12.0
# Total earning                13.0
# In.mean               2645.720904
# Name: 5, dtype: object

# %%
h.loc[567, ["Total Spent", "In.mean"]] # get the values of the row and column
# Out:
# Total Spent          83.37
# In.mean        2645.720904
# Name: 567, dtype: object

# %%
h.iloc[3,8] # get the value of the row and column
# Out:
# '10/24/2023'

# %%
h.iloc[[3,4]] # get the rows
# Out:
#   Customer ID       Category              Item  Quantity  Price Per Unit  \
# 3   CUST_0189        Fitness  Personal Trainer       5.0          155.46
# 4   CUST_0022  Subscriptions          Magazine       1.0            5.82
#
#    price  Total Spent  Payment Method Transaction Date   final  Total earning  \
# 3      6       777.29  Digital Wallet       10/24/2023  155.46         782.29
# 4      6         5.82      Debit Card        7/12/2023    5.82           6.82
#
#        In.mean
# 3  2645.720904
# 4  2645.720904

# %%
df.iloc[[3,4],7] # get the rows and column
# Out:
# 4    7/12/2023
# 5     9/1/2023
# Name: Transaction Date, dtype: object

# %% [markdown]
# ### _**Analyzing Data**_

# %%
h.groupby("Payment Method").describe() # group by payment method
# Out:
#                Quantity                                               \
#                   count      mean       std  min  25%  50%  75%  max
# Payment Method
# Cash              202.0  2.178218  1.444813  1.0  1.0  1.0  3.0  5.0
# Credit Card       193.0  2.440415  1.530191  1.0  1.0  2.0  4.0  5.0
# Debit Card        194.0  2.329897  1.525070  1.0  1.0  2.0  4.0  5.0
# Digital Wallet    214.0  2.289720  1.479178  1.0  1.0  2.0  4.0  5.0
#
#                Price Per Unit               ... Total earning             \
#                         count         mean  ...           75%        max
# Payment Method                              ...
# Cash                    194.0  1567.984639  ...      375.2450  202659.54
# Credit Card             209.0   710.152823  ...      280.3100   62683.74
# Debit Card              207.0   481.828937  ...      369.3375   39135.70
# Digital Wallet          215.0  1073.114837  ...      423.4475  139127.95
#
# ...

# %%
h.groupby('Quantity')['Total earning'].sum() # group by quantity
# Out:
# Quantity
# 1.0    296765.51
# 2.0    350129.12
# 3.0    516631.93
# 4.0    688617.95
# 5.0     52033.29
# Name: Total earning, dtype: float64

# %%
h.sort_values(by='Customer ID', ascending=False) # sort by customer ID
# Out:
#     Customer ID               Category           Item  Quantity  \
# 311   CUST_0200              Groceries     Vegetables       3.0
# 844   CUST_0200              Groceries         Snacks       5.0
# 133   CUST_0200              Groceries         Snacks       NaN
# 399   CUST_0199  Housing and Utilities       Gas Bill       1.0
# 630   CUST_0199         Medical/Dental       Medicine       1.0
# ..          ...                    ...            ...       ...
# 982         NaN               Shopping    Electronics       NaN
# 984         NaN                  Gifts     Kids Games       4.0
# 990         NaN              Groceries         Snacks       5.0
# 993         NaN                  Gifts     Gift Cards       3.0
# 995         NaN         Medical/Dental  Dentist Visit       1.0
#
#      Price Per Unit  price  Total Spent  Payment Method Transaction Date  \
# 311            5.45      6        16.34  Digital Wallet         5/6/2023
# ...

# %% [markdown]
# ### _**Visualization**_

# %%
h["Payment Method"].value_counts().plot(kind="line")  # plot the data
# Out:
# <Axes: xlabel='Payment Method'>

# %%
h["Category"].value_counts().plot(kind="bar") # plot the data
# Out:
# <Axes: xlabel='Category'>

# %%
h["Category"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
h["Category"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
h["Transaction Date"].value_counts().plot(kind="area")
# Out:
# <Axes: xlabel='Transaction Date'>

# %%
h["Category"].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
h["Transaction Date"].value_counts().plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### _**Final Export**_

# %%
df = pd.read_csv("pf.file.csv")
df
df.to_excel("project.xlsx", sheet_name="secsheet")
